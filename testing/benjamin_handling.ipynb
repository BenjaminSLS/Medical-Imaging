# %% [markdown]
# # Image masking
# - 1. Load image into array
# - 2. Convert image to grayscale
# - 3. Transform constrast of image
# - 4. Apply threshold to image
# - 5. Find contours
# - 6. Find largest contour
# - 7. Create mask

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from skimage import io, color, filters, feature, segmentation, measure

# %%
image = io.imread('./data/images/imgs_part_1/PAT_179_277_436.png')[:,:,:3]
image = color.rgb2gray(image,)
plt.imshow(image,cmap='gray')


# %matplotlib inline

# %%
p2, p98 = np.percentile(gray, (2, 98))
gray_rescale = exposure.rescale_intensity(gray, in_range=(p2, p98))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 p2, p98 = np.percentile(gray, (2, 98))
# ----> 2 gray_rescale = exposure.rescale_intensity(gray, in_range=(p2, p98))
#
# NameError: name 'exposure' is not defined
